# %% [markdown]
# # PyObject:  Object-oriented programming HW

# %% [markdown]
# ## Exercise 1  (from Monday's class)

# %% [markdown]
# 1. Write a ``Particle`` class that can be used to represent a particle with a mass, a 3-d position, and a 3-d velocity.
#
# 2. Write a method that can be used to compute the kinetic energy of the particle
#
# 3. Write a method that takes another particle as an argument and finds the distance between the two particles
#
# 4. Write a method that given a time interval ``dt`` will update the position of the particle to the new position based on the current position and velocity.
#
# 5. Write a ``ChargedParticle`` class that inherits from the ``Particle`` class, but also has an attribute for the charge of the particle.

# %%
import math

class Particle:
    def __init__(self, mass, position, velocity):
        self.mass = mass
        self.position = position
        self.velocity = velocity

    def kinetic_energy(self):
        return 0.5 * self.mass * sum(v ** 2 for v in self.velocity)

    def distance_to(self, other_particle):
        return math.sqrt(sum((a - b) ** 2 for a, b in zip(self.position, other_particle.position)))

    def update_position(self, dt):
        self.position = [p + v * dt for p, v in zip(self.position, self.velocity)]


class ChargedParticle(Particle):
    def __init__(self, mass, position, velocity, charge):
        super().__init__(mass, position, velocity)
        self.charge = charge
        

particle1 = Particle(mass=1.0, position=[0.0, 0.0, 0.0], velocity=[1.0, 0.0, 0.0])
particle2 = Particle(mass=2.0, position=[1.0, 0.0, 0.0], velocity=[0.0, 1.0, 0.0])

print("Kinetic Energy of Particle 1:", particle1.kinetic_energy())
print("Distance between Particle 1 and Particle 2:", particle1.distance_to(particle2))

particle1.update_position(dt=0.1)
print("Updated Position of Particle 1:", particle1.position)

charged_particle = ChargedParticle(mass=1.0, position=[0.0, 0.0, 0.0], velocity=[1.0, 0.0, 0.0], charge=1.5)
print("Charge of Charged Particle:", charged_particle.charge)
# Out:
# Kinetic Energy of Particle 1: 0.5
# Distance between Particle 1 and Particle 2: 1.0
# Updated Position of Particle 1: [0.1, 0.0, 0.0]
# Charge of Charged Particle: 1.5

# %% [markdown]
# ## Exercise 2  (New)

# %% [markdown]
# 6. Write a method that can be used to see if a particle is in the same place (e.g., find_seperation < 0.25).  If there are two ChargedParticles in the same place make a "simple" (*not correct physics*) "interaction". (__have the code print "interaction"__).
#
#     a. If the charges are opposite, make them "combine", set both velocities to zero and set their charge to zero, and print "merge".
#
#     b. Else, make the particles "repel", to do:
#
#         multiply each "self" velocity and  by (-1 * (self.charge+other.charge) * (self.mass/other.mass))
#
#         multiply each "other" velocity by (-1 * (self.charge+other.charge) * (other.mass/self.mass))
#
#     e.g., reversing it's velocity, and print "repel". __(Again this is bad physics, but we are focusing on coding so play along.)__
#
#
# 7. To test the above, write a code with two particles starting:
#
#         P1 at (x,y,z) = (-5,-5,-5) with (vx,vy,vz) = (1,1,1) and (charge = 0.5)
#
#         P2 at (x,y,z) = (5,5,5) with (vx,vy,vz) = (-1,-1,-1) and (charge = -0.5).
#
#     Use your dt time interval to move the particles in 0.25 time steps for 100 steps, and print the current poition and velocity of each particle at each time step.
#
#
# 8. To test the above, write a code with two particles starting:
#
#         P1 at (x,y,z) = (-5,-5,-5) with (vx,vy,vz) = (2,2,2) and (charge = 0.5)
#
#         P2 at (x,y,z) = (5,5,5) with (vx,vy,vz) = (-2,-2,-2) and (charge = 2.0).
#
#     Use your dt time interval to move the particles in 0.25 time steps for 100 steps, and print the current poition and velocity of each particle at each time step.

# %%
# write new code here

# %%
class ChargedParticle:
    def __init__(self, x, y, z, vx, vy, vz, charge):
        self.position = [x, y, z]
        self.velocity = [vx, vy, vz]
        self.charge = charge

    def interaction(self, other):
        separation = sum((a - b) ** 2 for a, b in zip(self.position, other.position)) ** 0.5
        if separation < 0.25:
            print("Interaction at Separation:", separation)
            if self.charge * other.charge < 0:  # Opposite charges
                print("Merge")
                self.velocity = [0.0, 0.0, 0.0]
                other.velocity = [0.0, 0.0, 0.0]
                self.charge = 0.0
                other.charge = 0.0
            else:
                print("Repel")
                factor_self = -1 * (self.charge + other.charge)
                factor_other = -1 * (self.charge + other.charge)
                self.velocity = [v * factor_self for v in self.velocity]
                other.velocity = [v * factor_other for v in other.velocity]

    def update_position(self, dt):
        for i in range(3):
            self.position[i] += self.velocity[i] * dt
        print(f"Position: {self.position}, Velocity: {self.velocity}")

particle1 = ChargedParticle(-5, -5, -5, 1, 1, 1, 0.5)
particle2 = ChargedParticle(5, 5, 5, -1, -1, -1, -0.5)
dt = 0.25
for _ in range(100):
    particle1.update_position(dt)
    particle2.update_position(dt)
    particle1.interaction(particle2)


particle3 = ChargedParticle(-5, -5, -5, 2, 2, 2, 0.5)
particle4 = ChargedParticle(5, 5, 5, -2, -2, -2, 2.0)
for _ in range(100):
    particle3.update_position(dt)
    particle4.update_position(dt)
    particle3.interaction(particle4)
# Out:
# Position: [-4.75, -4.75, -4.75], Velocity: [1, 1, 1]
# Position: [4.75, 4.75, 4.75], Velocity: [-1, -1, -1]
# Position: [-4.5, -4.5, -4.5], Velocity: [1, 1, 1]
# Position: [4.5, 4.5, 4.5], Velocity: [-1, -1, -1]
# Position: [-4.25, -4.25, -4.25], Velocity: [1, 1, 1]
# Position: [4.25, 4.25, 4.25], Velocity: [-1, -1, -1]
# Position: [-4.0, -4.0, -4.0], Velocity: [1, 1, 1]
# Position: [4.0, 4.0, 4.0], Velocity: [-1, -1, -1]
# Position: [-3.75, -3.75, -3.75], Velocity: [1, 1, 1]
# Position: [3.75, 3.75, 3.75], Velocity: [-1, -1, -1]
# Position: [-3.5, -3.5, -3.5], Velocity: [1, 1, 1]
# Position: [3.5, 3.5, 3.5], Velocity: [-1, -1, -1]
# Position: [-3.25, -3.25, -3.25], Velocity: [1, 1, 1]
# Position: [3.25, 3.25, 3.25], Velocity: [-1, -1, -1]
# Position: [-3.0, -3.0, -3.0], Velocity: [1, 1, 1]
# Position: [3.0, 3.0, 3.0], Velocity: [-1, -1, -1]
# Position: [-2.75, -2.75, -2.75], Velocity: [1, 1, 1]
# Position: [2.75, 2.75, 2.75], Velocity: [-1, -1, -1]
# Position: [-2.5, -2.5, -2.5], Velocity: [1, 1, 1]
# Position: [2.5, 2.5, 2.5], Velocity: [-1, -1, -1]
# Position: [-2.25, -2.25, -2.25], Velocity: [1, 1, 1]
# Position: [2.25, 2.25, 2.25], Velocity: [-1, -1, -1]
# Position: [-2.0, -2.0, -2.0], Velocity: [1, 1, 1]
# Position: [2.0, 2.0, 2.0], Velocity: [-1, -1, -1]
# Position: [-1.75, -1.75, -1.75], Velocity: [1, 1, 1]
# Position: [1.75, 1.75, 1.75], Velocity: [-1, -1, -1]
# Position: [-1.5, -1.5, -1.5], Velocity: [1, 1, 1]
# Position: [1.5, 1.5, 1.5], Velocity: [-1, -1, -1]
# Position: [-1.25, -1.25, -1.25], Velocity: [1, 1, 1]
# Position: [1.25, 1.25, 1.25], Velocity: [-1, -1, -1]
# Position: [-1.0, -1.0, -1.0], Velocity: [1, 1, 1]
# Position: [1.0, 1.0, 1.0], Velocity: [-1, -1, -1]
# Position: [-0.75, -0.75, -0.75], Velocity: [1, 1, 1]
# Position: [0.75, 0.75, 0.75], Velocity: [-1, -1, -1]
# Position: [-0.5, -0.5, -0.5], Velocity: [1, 1, 1]
# Position: [0.5, 0.5, 0.5], Velocity: [-1, -1, -1]
# Position: [-0.25, -0.25, -0.25], Velocity: [1, 1, 1]
# Position: [0.25, 0.25, 0.25], Velocity: [-1, -1, -1]
# Position: [0.0, 0.0, 0.0], Velocity: [1, 1, 1]
# Position: [0.0, 0.0, 0.0], Velocity: [-1, -1, -1]
# Interaction at Separation: 0.0
# Merge
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [0.0, 0.0, 0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Position: [0.0, 0.0, 0.0], Velocity: [-0.0, -0.0, -0.0]
# Interaction at Separation: 0.0
# Repel
# Position: [-4.5, -4.5, -4.5], Velocity: [2, 2, 2]
# Position: [4.5, 4.5, 4.5], Velocity: [-2, -2, -2]
# Position: [-4.0, -4.0, -4.0], Velocity: [2, 2, 2]
# Position: [4.0, 4.0, 4.0], Velocity: [-2, -2, -2]
# Position: [-3.5, -3.5, -3.5], Velocity: [2, 2, 2]
# Position: [3.5, 3.5, 3.5], Velocity: [-2, -2, -2]
# Position: [-3.0, -3.0, -3.0], Velocity: [2, 2, 2]
# Position: [3.0, 3.0, 3.0], Velocity: [-2, -2, -2]
# Position: [-2.5, -2.5, -2.5], Velocity: [2, 2, 2]
# Position: [2.5, 2.5, 2.5], Velocity: [-2, -2, -2]
# Position: [-2.0, -2.0, -2.0], Velocity: [2, 2, 2]
# Position: [2.0, 2.0, 2.0], Velocity: [-2, -2, -2]
# Position: [-1.5, -1.5, -1.5], Velocity: [2, 2, 2]
# Position: [1.5, 1.5, 1.5], Velocity: [-2, -2, -2]
# Position: [-1.0, -1.0, -1.0], Velocity: [2, 2, 2]
# Position: [1.0, 1.0, 1.0], Velocity: [-2, -2, -2]
# Position: [-0.5, -0.5, -0.5], Velocity: [2, 2, 2]
# Position: [0.5, 0.5, 0.5], Velocity: [-2, -2, -2]
# Position: [0.0, 0.0, 0.0], Velocity: [2, 2, 2]
# Position: [0.0, 0.0, 0.0], Velocity: [-2, -2, -2]
# Interaction at Separation: 0.0
# Repel
# Position: [-1.25, -1.25, -1.25], Velocity: [-5.0, -5.0, -5.0]
# Position: [1.25, 1.25, 1.25], Velocity: [5.0, 5.0, 5.0]
# Position: [-2.5, -2.5, -2.5], Velocity: [-5.0, -5.0, -5.0]
# Position: [2.5, 2.5, 2.5], Velocity: [5.0, 5.0, 5.0]
# Position: [-3.75, -3.75, -3.75], Velocity: [-5.0, -5.0, -5.0]
# Position: [3.75, 3.75, 3.75], Velocity: [5.0, 5.0, 5.0]
# Position: [-5.0, -5.0, -5.0], Velocity: [-5.0, -5.0, -5.0]
# Position: [5.0, 5.0, 5.0], Velocity: [5.0, 5.0, 5.0]
# Position: [-6.25, -6.25, -6.25], Velocity: [-5.0, -5.0, -5.0]
# Position: [6.25, 6.25, 6.25], Velocity: [5.0, 5.0, 5.0]
# Position: [-7.5, -7.5, -7.5], Velocity: [-5.0, -5.0, -5.0]
# Position: [7.5, 7.5, 7.5], Velocity: [5.0, 5.0, 5.0]
# Position: [-8.75, -8.75, -8.75], Velocity: [-5.0, -5.0, -5.0]
# Position: [8.75, 8.75, 8.75], Velocity: [5.0, 5.0, 5.0]
# Position: [-10.0, -10.0, -10.0], Velocity: [-5.0, -5.0, -5.0]
# Position: [10.0, 10.0, 10.0], Velocity: [5.0, 5.0, 5.0]
# Position: [-11.25, -11.25, -11.25], Velocity: [-5.0, -5.0, -5.0]
# Position: [11.25, 11.25, 11.25], Velocity: [5.0, 5.0, 5.0]
# Position: [-12.5, -12.5, -12.5], Velocity: [-5.0, -5.0, -5.0]
# Position: [12.5, 12.5, 12.5], Velocity: [5.0, 5.0, 5.0]
# Position: [-13.75, -13.75, -13.75], Velocity: [-5.0, -5.0, -5.0]
# Position: [13.75, 13.75, 13.75], Velocity: [5.0, 5.0, 5.0]
# Position: [-15.0, -15.0, -15.0], Velocity: [-5.0, -5.0, -5.0]
# Position: [15.0, 15.0, 15.0], Velocity: [5.0, 5.0, 5.0]
# Position: [-16.25, -16.25, -16.25], Velocity: [-5.0, -5.0, -5.0]
# Position: [16.25, 16.25, 16.25], Velocity: [5.0, 5.0, 5.0]
# Position: [-17.5, -17.5, -17.5], Velocity: [-5.0, -5.0, -5.0]
# Position: [17.5, 17.5, 17.5], Velocity: [5.0, 5.0, 5.0]
# Position: [-18.75, -18.75, -18.75], Velocity: [-5.0, -5.0, -5.0]
# Position: [18.75, 18.75, 18.75], Velocity: [5.0, 5.0, 5.0]
# Position: [-20.0, -20.0, -20.0], Velocity: [-5.0, -5.0, -5.0]
# Position: [20.0, 20.0, 20.0], Velocity: [5.0, 5.0, 5.0]
# Position: [-21.25, -21.25, -21.25], Velocity: [-5.0, -5.0, -5.0]
# Position: [21.25, 21.25, 21.25], Velocity: [5.0, 5.0, 5.0]
# Position: [-22.5, -22.5, -22.5], Velocity: [-5.0, -5.0, -5.0]
# Position: [22.5, 22.5, 22.5], Velocity: [5.0, 5.0, 5.0]
# Position: [-23.75, -23.75, -23.75], Velocity: [-5.0, -5.0, -5.0]
# Position: [23.75, 23.75, 23.75], Velocity: [5.0, 5.0, 5.0]
# Position: [-25.0, -25.0, -25.0], Velocity: [-5.0, -5.0, -5.0]
# Position: [25.0, 25.0, 25.0], Velocity: [5.0, 5.0, 5.0]
# Position: [-26.25, -26.25, -26.25], Velocity: [-5.0, -5.0, -5.0]
# Position: [26.25, 26.25, 26.25], Velocity: [5.0, 5.0, 5.0]
# Position: [-27.5, -27.5, -27.5], Velocity: [-5.0, -5.0, -5.0]
# Position: [27.5, 27.5, 27.5], Velocity: [5.0, 5.0, 5.0]
# Position: [-28.75, -28.75, -28.75], Velocity: [-5.0, -5.0, -5.0]
# Position: [28.75, 28.75, 28.75], Velocity: [5.0, 5.0, 5.0]
# Position: [-30.0, -30.0, -30.0], Velocity: [-5.0, -5.0, -5.0]
# Position: [30.0, 30.0, 30.0], Velocity: [5.0, 5.0, 5.0]
# Position: [-31.25, -31.25, -31.25], Velocity: [-5.0, -5.0, -5.0]
# Position: [31.25, 31.25, 31.25], Velocity: [5.0, 5.0, 5.0]
# Position: [-32.5, -32.5, -32.5], Velocity: [-5.0, -5.0, -5.0]
# Position: [32.5, 32.5, 32.5], Velocity: [5.0, 5.0, 5.0]
# Position: [-33.75, -33.75, -33.75], Velocity: [-5.0, -5.0, -5.0]
# Position: [33.75, 33.75, 33.75], Velocity: [5.0, 5.0, 5.0]
# Position: [-35.0, -35.0, -35.0], Velocity: [-5.0, -5.0, -5.0]
# Position: [35.0, 35.0, 35.0], Velocity: [5.0, 5.0, 5.0]
# Position: [-36.25, -36.25, -36.25], Velocity: [-5.0, -5.0, -5.0]
# Position: [36.25, 36.25, 36.25], Velocity: [5.0, 5.0, 5.0]
# Position: [-37.5, -37.5, -37.5], Velocity: [-5.0, -5.0, -5.0]
# Position: [37.5, 37.5, 37.5], Velocity: [5.0, 5.0, 5.0]
# Position: [-38.75, -38.75, -38.75], Velocity: [-5.0, -5.0, -5.0]
# Position: [38.75, 38.75, 38.75], Velocity: [5.0, 5.0, 5.0]
# Position: [-40.0, -40.0, -40.0], Velocity: [-5.0, -5.0, -5.0]
# Position: [40.0, 40.0, 40.0], Velocity: [5.0, 5.0, 5.0]
# Position: [-41.25, -41.25, -41.25], Velocity: [-5.0, -5.0, -5.0]
# Position: [41.25, 41.25, 41.25], Velocity: [5.0, 5.0, 5.0]
# Position: [-42.5, -42.5, -42.5], Velocity: [-5.0, -5.0, -5.0]
# Position: [42.5, 42.5, 42.5], Velocity: [5.0, 5.0, 5.0]
# Position: [-43.75, -43.75, -43.75], Velocity: [-5.0, -5.0, -5.0]
# Position: [43.75, 43.75, 43.75], Velocity: [5.0, 5.0, 5.0]
# Position: [-45.0, -45.0, -45.0], Velocity: [-5.0, -5.0, -5.0]
# Position: [45.0, 45.0, 45.0], Velocity: [5.0, 5.0, 5.0]
# Position: [-46.25, -46.25, -46.25], Velocity: [-5.0, -5.0, -5.0]
# Position: [46.25, 46.25, 46.25], Velocity: [5.0, 5.0, 5.0]
# Position: [-47.5, -47.5, -47.5], Velocity: [-5.0, -5.0, -5.0]
# Position: [47.5, 47.5, 47.5], Velocity: [5.0, 5.0, 5.0]
# Position: [-48.75, -48.75, -48.75], Velocity: [-5.0, -5.0, -5.0]
# Position: [48.75, 48.75, 48.75], Velocity: [5.0, 5.0, 5.0]
# Position: [-50.0, -50.0, -50.0], Velocity: [-5.0, -5.0, -5.0]
# Position: [50.0, 50.0, 50.0], Velocity: [5.0, 5.0, 5.0]
# Position: [-51.25, -51.25, -51.25], Velocity: [-5.0, -5.0, -5.0]
# Position: [51.25, 51.25, 51.25], Velocity: [5.0, 5.0, 5.0]
# Position: [-52.5, -52.5, -52.5], Velocity: [-5.0, -5.0, -5.0]
# Position: [52.5, 52.5, 52.5], Velocity: [5.0, 5.0, 5.0]
# Position: [-53.75, -53.75, -53.75], Velocity: [-5.0, -5.0, -5.0]
# Position: [53.75, 53.75, 53.75], Velocity: [5.0, 5.0, 5.0]
# Position: [-55.0, -55.0, -55.0], Velocity: [-5.0, -5.0, -5.0]
# Position: [55.0, 55.0, 55.0], Velocity: [5.0, 5.0, 5.0]
# Position: [-56.25, -56.25, -56.25], Velocity: [-5.0, -5.0, -5.0]
# Position: [56.25, 56.25, 56.25], Velocity: [5.0, 5.0, 5.0]
# Position: [-57.5, -57.5, -57.5], Velocity: [-5.0, -5.0, -5.0]
# Position: [57.5, 57.5, 57.5], Velocity: [5.0, 5.0, 5.0]
# Position: [-58.75, -58.75, -58.75], Velocity: [-5.0, -5.0, -5.0]
# Position: [58.75, 58.75, 58.75], Velocity: [5.0, 5.0, 5.0]
# Position: [-60.0, -60.0, -60.0], Velocity: [-5.0, -5.0, -5.0]
# Position: [60.0, 60.0, 60.0], Velocity: [5.0, 5.0, 5.0]
# Position: [-61.25, -61.25, -61.25], Velocity: [-5.0, -5.0, -5.0]
# Position: [61.25, 61.25, 61.25], Velocity: [5.0, 5.0, 5.0]
# Position: [-62.5, -62.5, -62.5], Velocity: [-5.0, -5.0, -5.0]
# Position: [62.5, 62.5, 62.5], Velocity: [5.0, 5.0, 5.0]
# Position: [-63.75, -63.75, -63.75], Velocity: [-5.0, -5.0, -5.0]
# Position: [63.75, 63.75, 63.75], Velocity: [5.0, 5.0, 5.0]
# Position: [-65.0, -65.0, -65.0], Velocity: [-5.0, -5.0, -5.0]
# Position: [65.0, 65.0, 65.0], Velocity: [5.0, 5.0, 5.0]
# Position: [-66.25, -66.25, -66.25], Velocity: [-5.0, -5.0, -5.0]
# Position: [66.25, 66.25, 66.25], Velocity: [5.0, 5.0, 5.0]
# Position: [-67.5, -67.5, -67.5], Velocity: [-5.0, -5.0, -5.0]
# Position: [67.5, 67.5, 67.5], Velocity: [5.0, 5.0, 5.0]
# Position: [-68.75, -68.75, -68.75], Velocity: [-5.0, -5.0, -5.0]
# Position: [68.75, 68.75, 68.75], Velocity: [5.0, 5.0, 5.0]
# Position: [-70.0, -70.0, -70.0], Velocity: [-5.0, -5.0, -5.0]
# Position: [70.0, 70.0, 70.0], Velocity: [5.0, 5.0, 5.0]
# Position: [-71.25, -71.25, -71.25], Velocity: [-5.0, -5.0, -5.0]
# Position: [71.25, 71.25, 71.25], Velocity: [5.0, 5.0, 5.0]
# Position: [-72.5, -72.5, -72.5], Velocity: [-5.0, -5.0, -5.0]
# Position: [72.5, 72.5, 72.5], Velocity: [5.0, 5.0, 5.0]
# Position: [-73.75, -73.75, -73.75], Velocity: [-5.0, -5.0, -5.0]
# Position: [73.75, 73.75, 73.75], Velocity: [5.0, 5.0, 5.0]
# Position: [-75.0, -75.0, -75.0], Velocity: [-5.0, -5.0, -5.0]
# Position: [75.0, 75.0, 75.0], Velocity: [5.0, 5.0, 5.0]
# Position: [-76.25, -76.25, -76.25], Velocity: [-5.0, -5.0, -5.0]
# Position: [76.25, 76.25, 76.25], Velocity: [5.0, 5.0, 5.0]
# Position: [-77.5, -77.5, -77.5], Velocity: [-5.0, -5.0, -5.0]
# Position: [77.5, 77.5, 77.5], Velocity: [5.0, 5.0, 5.0]
# Position: [-78.75, -78.75, -78.75], Velocity: [-5.0, -5.0, -5.0]
# Position: [78.75, 78.75, 78.75], Velocity: [5.0, 5.0, 5.0]
# Position: [-80.0, -80.0, -80.0], Velocity: [-5.0, -5.0, -5.0]
# Position: [80.0, 80.0, 80.0], Velocity: [5.0, 5.0, 5.0]
# Position: [-81.25, -81.25, -81.25], Velocity: [-5.0, -5.0, -5.0]
# Position: [81.25, 81.25, 81.25], Velocity: [5.0, 5.0, 5.0]
# Position: [-82.5, -82.5, -82.5], Velocity: [-5.0, -5.0, -5.0]
# Position: [82.5, 82.5, 82.5], Velocity: [5.0, 5.0, 5.0]
# Position: [-83.75, -83.75, -83.75], Velocity: [-5.0, -5.0, -5.0]
# Position: [83.75, 83.75, 83.75], Velocity: [5.0, 5.0, 5.0]
# Position: [-85.0, -85.0, -85.0], Velocity: [-5.0, -5.0, -5.0]
# Position: [85.0, 85.0, 85.0], Velocity: [5.0, 5.0, 5.0]
# Position: [-86.25, -86.25, -86.25], Velocity: [-5.0, -5.0, -5.0]
# Position: [86.25, 86.25, 86.25], Velocity: [5.0, 5.0, 5.0]
# Position: [-87.5, -87.5, -87.5], Velocity: [-5.0, -5.0, -5.0]
# Position: [87.5, 87.5, 87.5], Velocity: [5.0, 5.0, 5.0]
# Position: [-88.75, -88.75, -88.75], Velocity: [-5.0, -5.0, -5.0]
# Position: [88.75, 88.75, 88.75], Velocity: [5.0, 5.0, 5.0]
# Position: [-90.0, -90.0, -90.0], Velocity: [-5.0, -5.0, -5.0]
# Position: [90.0, 90.0, 90.0], Velocity: [5.0, 5.0, 5.0]
# Position: [-91.25, -91.25, -91.25], Velocity: [-5.0, -5.0, -5.0]
# Position: [91.25, 91.25, 91.25], Velocity: [5.0, 5.0, 5.0]
# Position: [-92.5, -92.5, -92.5], Velocity: [-5.0, -5.0, -5.0]
# Position: [92.5, 92.5, 92.5], Velocity: [5.0, 5.0, 5.0]
# Position: [-93.75, -93.75, -93.75], Velocity: [-5.0, -5.0, -5.0]
# Position: [93.75, 93.75, 93.75], Velocity: [5.0, 5.0, 5.0]
# Position: [-95.0, -95.0, -95.0], Velocity: [-5.0, -5.0, -5.0]
# Position: [95.0, 95.0, 95.0], Velocity: [5.0, 5.0, 5.0]
# Position: [-96.25, -96.25, -96.25], Velocity: [-5.0, -5.0, -5.0]
# Position: [96.25, 96.25, 96.25], Velocity: [5.0, 5.0, 5.0]
# Position: [-97.5, -97.5, -97.5], Velocity: [-5.0, -5.0, -5.0]
# Position: [97.5, 97.5, 97.5], Velocity: [5.0, 5.0, 5.0]
# Position: [-98.75, -98.75, -98.75], Velocity: [-5.0, -5.0, -5.0]
# Position: [98.75, 98.75, 98.75], Velocity: [5.0, 5.0, 5.0]
# Position: [-100.0, -100.0, -100.0], Velocity: [-5.0, -5.0, -5.0]
# Position: [100.0, 100.0, 100.0], Velocity: [5.0, 5.0, 5.0]
# Position: [-101.25, -101.25, -101.25], Velocity: [-5.0, -5.0, -5.0]
# Position: [101.25, 101.25, 101.25], Velocity: [5.0, 5.0, 5.0]
# Position: [-102.5, -102.5, -102.5], Velocity: [-5.0, -5.0, -5.0]
# Position: [102.5, 102.5, 102.5], Velocity: [5.0, 5.0, 5.0]
# Position: [-103.75, -103.75, -103.75], Velocity: [-5.0, -5.0, -5.0]
# Position: [103.75, 103.75, 103.75], Velocity: [5.0, 5.0, 5.0]
# Position: [-105.0, -105.0, -105.0], Velocity: [-5.0, -5.0, -5.0]
# Position: [105.0, 105.0, 105.0], Velocity: [5.0, 5.0, 5.0]
# Position: [-106.25, -106.25, -106.25], Velocity: [-5.0, -5.0, -5.0]
# Position: [106.25, 106.25, 106.25], Velocity: [5.0, 5.0, 5.0]
# Position: [-107.5, -107.5, -107.5], Velocity: [-5.0, -5.0, -5.0]
# Position: [107.5, 107.5, 107.5], Velocity: [5.0, 5.0, 5.0]
# Position: [-108.75, -108.75, -108.75], Velocity: [-5.0, -5.0, -5.0]
# Position: [108.75, 108.75, 108.75], Velocity: [5.0, 5.0, 5.0]
# Position: [-110.0, -110.0, -110.0], Velocity: [-5.0, -5.0, -5.0]
# Position: [110.0, 110.0, 110.0], Velocity: [5.0, 5.0, 5.0]
# Position: [-111.25, -111.25, -111.25], Velocity: [-5.0, -5.0, -5.0]
# Position: [111.25, 111.25, 111.25], Velocity: [5.0, 5.0, 5.0]
# Position: [-112.5, -112.5, -112.5], Velocity: [-5.0, -5.0, -5.0]
# Position: [112.5, 112.5, 112.5], Velocity: [5.0, 5.0, 5.0]
